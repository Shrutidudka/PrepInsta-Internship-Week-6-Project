# %% [markdown]
# ### **Univariate Analysis**

# %% [markdown]
# 1. Understand Dataset:

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Dataset**

# %%
import plotly
import plotly.express as px
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
df
# Out:
#       Unnamed: 0        Make      Model        Variant Ex-Showroom_Price  \
# 0              0        Tata  Nano Genx             Xt      Rs. 2,92,667
# 1              1        Tata  Nano Genx             Xe      Rs. 2,36,447
# 2              2        Tata  Nano Genx        Emax Xm      Rs. 2,96,661
# 3              3        Tata  Nano Genx            Xta      Rs. 3,34,768
# 4              4        Tata  Nano Genx             Xm      Rs. 2,72,223
# ...          ...         ...        ...            ...               ...
# 1271        1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000
# 1274        1274       Honda       City   V Cvt Petrol     Rs. 12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      Yes                 Yes
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 141 entries, Unnamed: 0 to Electric_Range
# dtypes: float64(6), int64(1), object(134)
# memory usage: 1.4+ MB

# %% [markdown]
# 4. Descriptive Statistics:

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder        Doors  \
# count  1276.000000  1276.000000          1276.000000  1276.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.617396             0.799718     0.746642
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        Seating_Capacity  Number_of_Airbags    USB_Ports
# count       1276.000000        1276.000000  1276.000000
# mean           5.270079           3.787029     1.793103
# std            1.142533           2.385125     0.114647
# min            2.000000           1.000000     1.000000
# 25%            5.000000           2.000000     1.793103
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
df.nunique()
# Out:
# Unnamed: 0           1276
# Make                   39
# Model                 263
# Variant              1064
# Ex-Showroom_Price    1179
#                      ...
# USB_Ports               4
# Heads-Up_Display        1
# Welcome_Lights          1
# Battery                 5
# Electric_Range          8
# Length: 141, dtype: int64

# %%
df[df.duplicated()].count()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
df[df.isnull()].count()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
df=df.fillna('')
df=df.replace(' ', '')

# %%
df[df.Make =='Tata'].tail()
# Out:
#       Unnamed: 0  Make      Model                Variant Ex-Showroom_Price  \
# 1141        1141  Tata    Harrier  Revotorq Dark Edition     Rs. 17,30,755
# 1187        1187  Tata  Tiago Nrg          1.2L Revotron      Rs. 5,94,993
# 1188        1188  Tata  Tiago Nrg         1.05L Revotorq      Rs. 6,89,993
# 1189        1189  Tata  Tiago Nrg      1.2L Revotron Amt      Rs. 6,39,993
# 1204        1204  Tata     Winger                    15S     Rs. 12,05,000
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 1141      1956 cc        3.0             4.000000  FWD (Front Wheel Drive)
# 1187      1199 cc        3.0             4.000000  FWD (Front Wheel Drive)
# 1188      1047 cc        3.0             4.000000  FWD (Front Wheel Drive)
# 1189      1199 cc        3.0             4.000000  FWD (Front Wheel Drive)
# 1204      2200 cc        4.0             3.977853  FWD (Front Wheel Drive)
#
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 7))

# Pie chart for Car Makes
top_n = 5
top_makers = df['Make'].value_counts().head(top_n)
ax.pie(top_makers, labels=top_makers.index, autopct='%1.1f%%', startangle=90)
ax.set_title(f'Top {top_n} Car Makers Distribution')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))

# Pie chart for Car Models
model_counts = df['Model'].value_counts().head(10)  # Displaying top 10 models for example
ax.pie(model_counts, labels=model_counts.index, autopct='%1.1f%%', startangle=90)
ax.set_title('Top Car Models Distribution')

plt.show()

# %% [markdown]
# 2. Data Cleaning:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
# Impute missing values in numerical columns with the mean
df.fillna(df.mean(), inplace=True)

# Impute missing values in categorical columns with the mode
df.fillna(df.mode().iloc[0], inplace=True)
# Out:
# <ipython-input-20-825f7f6d2dc9>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
df.to_csv('/content/drive/MyDrive/cars_ds_final.csv', index=False)

# %%
df_cleaned_rows = df.dropna()

# %%
import plotly
import plotly.express as px
from matplotlib.pyplot import figure

# %%
from sklearn.impute import SimpleImputer
# Remove Rows with Missing Values
df_cleaned_rows = df.dropna()

# Impute Missing Values (using mean as an example)
df_cleaned = df.select_dtypes(include=np.number)
imputer = SimpleImputer(strategy="mean")
df_imputed = pd.DataFrame(imputer.fit_transform(df_cleaned), columns=df_cleaned.columns)

# Display the first few rows of the cleaned/imputed DataFrames
print("Cleaned DataFrame (removing rows):")
print(df_cleaned_rows.head())

print("Imputed DataFrame:")
print(df_imputed.head())
# Out:
# Cleaned DataFrame (removing rows):
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# ...

# %% [markdown]
# 3. Data Types:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
# Display data types of each column
data_types = df.dtypes
print("Data Types:")
print(data_types)
# Out:
# Data Types:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
# Checking for any non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['number']).columns
print("\nNon-Numeric Columns:")
print(non_numeric_columns)
# Out:
# Non-Numeric Columns:
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Drivetrain', 'Cylinder_Configuration', 'Emission_Norm',
#        'Engine_Location', 'Fuel_System',
#        ...
#        'Paddle_Shifters', 'Leather_Wrapped_Steering', 'Automatic_Headlamps',
#        'Engine_Type', 'ASR_/_Traction_Control', 'Cruise_Control',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=134)

# %%
# Check the data types of each column
data_types = df.dtypes
print(data_types)
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
# Convert 'categorical_column' to categorical data type
df.rename(columns={'categorical_column': 'new_column_name'}, inplace=True)

# %%
# Check if 'date_column' exists in the DataFrame
if 'date_column' in df.columns:
    # Convert 'date_column' to DateTime format
    df['date_column'] = pd.to_datetime(df['date_column'])

# %%
# Convert 'numeric_column' to numeric type
if 'numeric_column' in df.columns:
    df['numeric_column'] = pd.to_numeric(df['numeric_column'], errors='coerce')

# %%
df['column_with_missing_values'] = np.nan                          # Impute with a specific value
df.dropna(subset=['column_with_missing_values'], inplace=True)     # Drop rows with missing values

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# Make                           object
# Model                          object
# Variant                        object
# Ex-Showroom_Price              object
#                                ...
# Heads-Up_Display               object
# Welcome_Lights                 object
# Battery                        object
# Electric_Range                 object
# column_with_missing_values    float64
# Length: 142, dtype: object

# %% [markdown]
# 4. Descriptive Statistics:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder        Doors  \
# count  1276.000000  1276.000000          1276.000000  1276.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.617396             0.799718     0.746642
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        Seating_Capacity  Number_of_Airbags    USB_Ports
# count       1276.000000        1276.000000  1276.000000
# mean           5.270079           3.787029     1.793103
# std            1.142533           2.385125     0.114647
# min            2.000000           1.000000     1.000000
# 25%            5.000000           2.000000     1.793103
# ...

# %%
# Calculate mean for all numeric columns
mean_values = df.mean()
print("Mean:")
print(mean_values)
# Out:
# Mean:
# Unnamed: 0             637.500000
# Cylinders                4.380992
# Valves_Per_Cylinder      3.977853
# Doors                    4.550314
# Seating_Capacity         5.270079
# Number_of_Airbags        3.787029
# USB_Ports                1.793103
# dtype: float64
# <ipython-input-40-4194db8459f6>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = df.mean()

# %%
# Calculate median for all numeric columns
median_values = df.median()
print("Median:")
print(median_values)
# Out:
# Median:
# Unnamed: 0             637.500000
# Cylinders                4.000000
# Valves_Per_Cylinder      4.000000
# Doors                    5.000000
# Seating_Capacity         5.000000
# Number_of_Airbags        2.000000
# USB_Ports                1.793103
# dtype: float64
# <ipython-input-41-613f4697995c>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_values = df.median()

# %%
# Calculate mode for all numeric columns
mode_values = df.mode().iloc[0]
print("Mode:")
print(mode_values)
# Out:
# Mode:
# Unnamed: 0                            0
# Make                      Maruti Suzuki
# Model                             Nexon
# Variant                             Lxi
# Ex-Showroom_Price          Rs. 9,99,900
#                             ...
# USB_Ports                      1.793103
# Heads-Up_Display                    Yes
# Welcome_Lights                      Yes
# Battery                 200 ampere-hour
# Electric_Range       110 km/full charge
# Name: 0, Length: 141, dtype: object

# %%
# Calculate minimum for all numeric columns
min_values = df.min()
print("Minimum:")
print(min_values)
# Out:
# Minimum:
# Unnamed: 0                              0
# Make                         Aston Martin
# Model                            3-Series
# Variant                             1.0 S
# Ex-Showroom_Price         Rs. 1,01,44,987
#                              ...
# USB_Ports                             1.0
# Heads-Up_Display                      Yes
# Welcome_Lights                        Yes
# Battery                   200 ampere-hour
# Electric_Range       11.68 km/full charge
# Length: 141, dtype: object

# %%
# Calculate maximum for all numeric columns
max_values = df.max()
print("Maximum:")
print(max_values)
# Out:
# Maximum:
# Unnamed: 0                              1275
# Make                                   Volvo
# Model                                  Zs Ev
# Variant                         Zxi Plus Amt
# Ex-Showroom_Price              Rs. 99,00,000
#                               ...
# USB_Ports                                3.0
# Heads-Up_Display                         Yes
# Welcome_Lights                           Yes
# Battery              44.5 (kWh), Lithium Ion
# Electric_Range            462 km/full charge
# Length: 141, dtype: object

# %%
# Calculate standard deviation for all numeric columns
std_deviation_values = df.std()
print("Standard Deviation:")
print(std_deviation_values)
# Out:
# Standard Deviation:
# Unnamed: 0             368.493781
# Cylinders                1.617396
# Valves_Per_Cylinder      0.799718
# Doors                    0.746642
# Seating_Capacity         1.142533
# Number_of_Airbags        2.385125
# USB_Ports                0.114647
# dtype: float64
# <ipython-input-45-54ac8ae7a325>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   std_deviation_values = df.std()

# %% [markdown]
# 5. Histograms:

# %%
# Assuming you have a DataFrame named 'df'
# Replace this with your actual DataFrame
df = pd.DataFrame({
    'numeric_column_1': [10, 15, 20, 25, 30],
    'numeric_column_2': [50, 45, 60, 70, 55],
})

# %%
numeric_columns_to_visualize = ['numeric_column_1', 'numeric_column_2']

# %%
plt.figure(figsize=(15, 5))

sns.set(style="whitegrid")

for i, column in enumerate(numeric_columns_to_visualize, 1):
    plt.subplot(1, len(numeric_columns_to_visualize), i)
    plt.hist(df[column], bins=20, edgecolor='black', color='purple')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.tight_layout()

plt.show()

# %% [markdown]
# 6. Bar Charts:

# %%
# Assume you have a DataFrame named 'df' with actual categorical column names
df = pd.DataFrame({
    'categorical_column_1': ['Category_A', 'Category_B', 'Category_A', 'Category_A', 'Category_B'],
    'categorical_column_2': ['Type_X', 'Type_Y', 'Type_X', 'Type_Y', 'Type_X'],
    'categorical_column_3': ['Label_1', 'Label_2', 'Label_1', 'Label_3', 'Label_2'],
})

# %%
# Specify key categorical columns to visualize
categorical_columns_to_visualize = ['categorical_column_1', 'categorical_column_2', 'categorical_column_3']
categorical_columns_to_visualize = ['categorical_column_1', 'categorical_column_2']

category_counts = df[categorical_columns_to_visualize].apply(pd.value_counts)

category_counts.T.plot(kind='bar', stacked=True, figsize=(8, 3), colormap="viridis")

plt.title('Count of Categorical Variables', fontsize=16)
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend(title='Categorical Variable', bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# 7. Box Plots:

# %%
# Assuming 'df' is your DataFrame
df = pd.DataFrame({
    'numeric_column_1': [5, 10, 15, 20, 25, 30, 35, 40, 45],
    'numeric_column_2': [100, 150, 200, 250, 300, 350, 400, 450, 500],
    'numeric_column_3': [10, 20, 30, 40, 50, 60, 70, 80, 90],
})

# %%
#'numeric_columns_to_visualize' is a list of numeric column names
numeric_columns_to_visualize = ['numeric_column_1', 'numeric_column_2']

sns.set(style="whitegrid")
colors = sns.color_palette("husl")

plt.figure(figsize=(8, 5))
sns.boxplot(data=df[numeric_columns_to_visualize], palette=colors)

plt.title('Box Plots of Numeric Variables', fontsize=16)
plt.xlabel('Values')

plt.show()
# Out:
# <ipython-input-190-acc8e8c4cae5>:8: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.boxplot(data=df[numeric_columns_to_visualize], palette=colors)

# %% [markdown]
# 8. Pie Charts:

# %%
# Assuming you have a DataFrame named 'df' with categorical columns
# Replace 'car_model', 'manufacturer', etc. with your actual column names
df = pd.DataFrame({
    'car_model': ['Sedan', 'SUV', 'Hatchback', 'Sedan', 'SUV', 'SUV', 'Hatchback', 'Sedan'],
    'manufacturer': ['Toyota', 'Honda', 'Ford', 'Toyota', 'Honda', 'Ford', 'Nissan', 'Toyota'],
    'color': ['Red', 'Blue', 'Black', 'White', 'Red', 'Blue', 'Black', 'White']
})

# %%
# Specify the categorical column to visualize
categorical_column_to_visualize = 'car_model'

category_contribution = df[categorical_column_to_visualize].value_counts()

custom_colors = ['#FF9999', '#66B2FF', '#99FF99', '#FFCC99']

plt.figure(figsize=(7, 5))
plt.pie(category_contribution, labels=category_contribution.index, autopct='%1.1f%%', startangle=90, colors=custom_colors,
        wedgeprops=dict(width=0.3, edgecolor='w'))

plt.title(f'Contribution of {categorical_column_to_visualize}', fontsize=16)
plt.ylabel('')

plt.show()

# %% [markdown]
# 9. Count Plots:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
(df.columns)
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Ex-Showroom_Price',
#        'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=141)

# %%
(df.dtypes)
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
df.rename(columns={'category_column': 'new_column_name'}, inplace=True)

# %%
plt.figure(figsize=(15, 5))

# Calculate the counts for each 'Body_Type'
body_type_counts = df['Body_Type'].value_counts()

custom_colors = sns.color_palette("mako", n_colors=len(body_type_counts))

sns.countplot(data=df, y='Body_Type', alpha=0.6, palette=custom_colors, order=body_type_counts.index)

plt.title('Categorical Variables', fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('')
plt.ylabel('')

plt.show()
# Out:
# <ipython-input-93-5401f1e0caf6>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='Body_Type', alpha=0.6, palette=custom_colors, order=body_type_counts.index)

# %% [markdown]
# ### **Bivariate Analysis**

# %% [markdown]
# 1. Correlation Matrix:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      Yes                 Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 141 entries, Unnamed: 0 to Electric_Range
# dtypes: float64(6), int64(1), object(134)
# memory usage: 1.4+ MB

# %%
df.nunique()
# Out:
# Unnamed: 0           1276
# Make                   39
# Model                 263
# Variant              1064
# Ex-Showroom_Price    1179
#                      ...
# USB_Ports               4
# Heads-Up_Display        1
# Welcome_Lights          1
# Battery                 5
# Electric_Range          8
# Length: 141, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-98-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Unnamed: 0  Cylinders  Valves_Per_Cylinder     Doors  \
# Unnamed: 0             1.000000   0.124555         2.060722e-02 -0.087008
# Cylinders              0.124555   1.000000        -8.845347e-04 -0.500707
# Valves_Per_Cylinder    0.020607  -0.000885         1.000000e+00 -0.029219
# Doors                 -0.087008  -0.500707        -2.921924e-02  1.000000
# Seating_Capacity       0.065987  -0.315372        -2.323861e-02  0.521254
# Number_of_Airbags      0.191129   0.434255         6.320308e-02 -0.209560
# USB_Ports              0.011054  -0.068259        -5.921562e-17  0.100471
#
#                      Seating_Capacity  Number_of_Airbags     USB_Ports
# ...

# %%
correlation_matrix = df.corr()
# Out:
# <ipython-input-99-68bbfff3c4eb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
sns.set(style='darkgrid')
colors = sns.color_palette('magma')

fig, ax = plt.subplots(figsize=(8, 5))

sns.heatmap(correlation_matrix, annot=True, cmap=colors, linewidths=.5)

plt.title('Correlation Matrix', fontsize=16)

plt.show()

# %% [markdown]
# 2. Scatter Plots:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
# sample data
np.random.seed(42)
x = np.random.rand(50)  # Random values for the x-axis
y = 2 * x + 1 + 0.1 * np.random.randn(50)  # Linear relationship with some noise

# %%
sns.set(style='whitegrid')
colors = sns.color_palette('viridis')

plt.figure(figsize=(7, 5))
sns.scatterplot(x=x, y=y, color=colors[0], marker='o', label='Data Points')

plt.title('Scatter Plot: Relationship between X and Y', fontsize=16)
plt.xlabel('X-axis', fontsize=8)
plt.ylabel('Y-axis', fontsize=8)

plt.legend()
plt.show()

# %% [markdown]
# 3. Pair Plots:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load the Iris dataset from Scikit-learn
iris_sklearn = load_iris()

# Create a DataFrame from the data and feature names
iris = pd.DataFrame(data=iris_sklearn.data, columns=iris_sklearn.feature_names)

# Add the 'target' column to the DataFrame
iris['target'] = iris_sklearn.target

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 8))
sns.pairplot(iris, hue='target', palette={0: 'blue', 1: 'blue', 2: 'blue'}, markers=["o", "s", "D"])
plt.suptitle('Pair Plot of Iris Dataset', y=1.02, fontsize=16)

plt.show()

# %% [markdown]
# 4. Bar Charts with Hue:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
# sample data
data = {
    'Category': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Value': [10, 15, 20, 25, 30, 35],
    'Additional_Category': ['X', 'Y', 'X', 'Y', 'X', 'Y']
}

# %%
# Convert data to a DataFrame
df = pd.DataFrame(data)

# %%
# Assuming 'df' is your DataFrame
sns.set(style='whitegrid')
colors = sns.color_palette('deep')

# Create a bar chart with the 'hue' parameter
plt.figure(figsize=(8, 5))
sns.barplot(x='Category', y='Value', hue='Additional_Category', data=df, palette=colors)

plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Bar Chart with Hue Parameter')

plt.show()
# Out:
# <ipython-input-128-85c0d453c6c0>:7: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.barplot(x='Category', y='Value', hue='Additional_Category', data=df, palette=colors)

# %% [markdown]
# 5. Heatmaps:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
# Generate random data
np.random.seed(42)
data = np.random.rand(10, 5)

# %%
# Calculate the correlation matrix
correlation_matrix = np.corrcoef(data, rowvar=False)

# %%
# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', xticklabels=False, yticklabels=False)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# 6. Joint Plots:

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %%
# Generate random data for demonstration
np.random.seed(42)
x = np.random.rand(100)
y = 2 * x + 1 + 0.1 * np.random.randn(100)  # Linear relationship with some noise
data = np.column_stack((x, y))

# %%
sns.set(style='darkgrid', palette='plasma')
sns.jointplot(x=data[:, 0], y=data[:, 1], kind='scatter', marginal_kws=dict(bins=15, fill=False))
plt.show()

# %% [markdown]
# 7. Box Plots with Hue:

# %%
# sample data
data = {
    'Day': ['Thur', 'Fri', 'Sat', 'Sun', 'Thur', 'Fri', 'Sat', 'Sun'],
    'Total_Bill': [20.0, 15.5, 40.8, 50.2, 18.7, 25.0, 35.5, 45.0],
    'Sex': ['Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female']
}
df = pd.DataFrame(data)

# %%
# Create a box plot with hue
sns.boxplot(x='Day', y='Total_Bill', hue='Sex', data=df, palette=colors)
plt.title('Box Plot with Hue')
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.legend(title='Sex', loc='upper right')
plt.show()
# Out:
# <ipython-input-144-8c5695adbffa>:2: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.boxplot(x='Day', y='Total_Bill', hue='Sex', data=df, palette=colors)

# %% [markdown]
# 8. Categorical Plots:

# %%
np.random.seed(42)
categories = np.random.choice(['A', 'B', 'C'], size=100)
values = np.random.normal(loc=0, scale=1, size=100)

df = pd.DataFrame({'categorical_variable': categories, 'numeric_variable': values})

# %%
# Box Plot
sns.boxplot(x='categorical_variable', y='numeric_variable', data=df)
plt.show()

# Violin Plot
sns.violinplot(x='categorical_variable', y='numeric_variable', data=df)
plt.show()

# %%
# Bar Plot with Error Bars
sns.barplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd', palette=colors)
plt.show()

# Count Plot
sns.countplot(x='categorical_variable', data=df, palette=colors)
plt.show()

# Point Plot
sns.pointplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd', palette=colors)
plt.show()
# Out:
# <ipython-input-151-5998279c7977>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd', palette=colors)
# <ipython-input-151-5998279c7977>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd', palette=colors)
# <ipython-input-151-5998279c7977>:2: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.barplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd', palette=colors)
# <ipython-input-151-5998279c7977>:6: FutureWarning:
#
# ...

# %% [markdown]
# 9. Violin Plots:

# %%
# data (replace this with your actual data)
data = pd.DataFrame({
    'Category': ['A']*100 + ['B']*150 + ['C']*200,
    'Numeric_Variable': list(np.random.randn(100)) + list(np.random.randn(150) + 2) + list(np.random.randn(200) - 2)
})

# %%
# Create a violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='Category', y='Numeric_Variable', data=data, palette=colors)
plt.title('Distribution of Numeric Variable Across different Categories')
plt.xlabel('Category')
plt.ylabel('Numeric Variable')
plt.show()
# Out:
# <ipython-input-150-c30fc8400a70>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Category', y='Numeric_Variable', data=data, palette=colors)
# <ipython-input-150-c30fc8400a70>:3: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.violinplot(x='Category', y='Numeric_Variable', data=data, palette=colors)

# %% [markdown]
# 10. Stacked Bar Charts:

# %%
# data
data = pd.DataFrame({
    'Category': ['A', 'B', 'C'],
    'Contribution_1': [30, 40, 25],
    'Contribution_2': [20, 35, 30],
    'Contribution_3': [15, 25, 20],
})

# %%
# Create a stacked bar chart
plt.figure(figsize=(10, 6))
bottom = [0] * len(data['Category'])

# %%
for i, column in enumerate(data.columns[1:]):
    plt.bar(data['Category'], data[column], label=column, bottom=bottom)
    bottom = [sum(x) for x in zip(bottom, data[column])]

plt.title('Combined Contribution of Different Categories')
plt.xlabel('DifferentCategory')
plt.ylabel('Contribution')
plt.legend(title='Contributions', loc='upper right')
plt.show()

# %% [markdown]
# 11. Insights and Documentation:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/cars_ds_final.csv')

# %% [markdown]
# Univariate Analysis:

# %%
# Display descriptive statistics for numeric variables
desc_stats = iris.describe()
print(desc_stats)
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 141 entries, Unnamed: 0 to Electric_Range
# dtypes: float64(6), int64(1), object(134)
# memory usage: 1.4+ MB

# %%
# Check the column names in your DataFrame
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Ex-Showroom_Price',
#        'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=141)

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Correlation Matrix Heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Calculate correlation matrix
correlation_matrix = iris.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# *Scatter* Plot

# %%
# Creating a scatter plot
plt.scatter(x, y, alpha=0.5)
plt.title('Scatter Plot of Two Numeric Variables')
plt.xlabel('X-axis Label')  # Replace with your variable name
plt.ylabel('Y-axis Label')  # Replace with your variable name
plt.grid(True)
plt.show()

# %% [markdown]
# Correlation Matrix Headmap

# %%
# Correlation matrix for numerical variables
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-184-593759b37024>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
